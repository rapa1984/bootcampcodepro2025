# %%
carnes_tipo_de_cortes =  ["rabadilla","peceto","lomo","costilla","paleta"]
print(carnes_tipo_de_cortes)

carnes_tipo_de_cortes.append("lomito")

carnes_tipo_de_cortes [1]

carnes_tipo_de_cortes.pop(2)
# Out:
# ['rabadilla', 'peceto', 'lomo', 'costilla', 'paleta']
# 'lomo'

# %%
dias_de_la_semana = ("lunes")
for dia in dias_de_la_semana
    print(dias_de_la_semana)
# Out:
#   Cell In[44], line 2
#     for dia in dias_de_la_semana
#                                 ^
# SyntaxError: expected ':'

# %%
def saludo_bienvenida(nombre):
    print(f"buen dia" {nombre})

# %%
for i in range(10):
    resultado= i * 2
    print ("el resultado es")
# Out:
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es
# el resultado es

# %%
# Out:
#   Cell In[37], line 10
#     print (lista_de_marcas)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 9

# %%
#crear una lista de marcas 
#recorrer la lista de marcas 
#crear una condicion , si la palabra tiene mas de 6 caracteres
#imprimir solamente la palabra con 6 caracteres

lista_de_marcas = ("toyota","nissan","audi","opel","bmw") 
for lista_de_marcas in lista_de_marcas:
     
    if len (lista_de_marcas) >= 6:
         print(lista_de_marcas)
# Out:
# toyota
# nissan

# %%
usuario = input("ingresa una frase")
for letra in  usuario:
   if letra== "o":
      print("encontre una o")
   
   #estuvo bien pesado el dia , auxilio!
# Out:
# encontre una o
# encontre una o
# encontre una o

# %%
edad = 18

if edad < 18:
    print("no puede consumir alcohol, solo juguito")
elif edad >= 21:
     print("podes comprar ,pero no tomar")
else:
     print("puede hacer lo que quiera")
# Out:
# puede hacer lo que quiera

# %%
termometro_del_usuario = int (input("cual es la tempratura en celsius?"))
print(f"la temperatura celsius es {termometro_del_usuario}")
if termometro_del_usuario >= -10 and termometro_del_usuario<=20:
    print("refrescai")
elif termometro_del_usuario >=18 and termometro_del_usuario<=30:
    print("calor,i")
elif termometro_del_usuario >=32 and termometro_del_usuario<=44:
    print("hakuro")
else:
    print("ñamano mbae")
# Out:
# la temperatura celsius es -5
# refrescai

# %%
contraseña_secreta2 = 11
usuario2 = 5
print("la contraseña correcta es")
contraseña_secreta2 =  (input(usuario2))
while contraseña_secreta2 != usuario2:
      print ("contraseña incorrecta")
contraseña_secreta2 = input ("introduzca la contraseña de dos digitos")
print("contraseña correcta")
# Out:
# la contraseña correcta es
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# ...
